# %% [markdown]
# <a href="https://colab.research.google.com/github/ayush2281/Machine-Learning-libraries-/blob/main/PandasLib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pandas Library
# Usefull for data Processing & Analysis
#
# Pandas Data Frame:
# Pandas DataFrame is Two-dimensional tabular with labeled axes (rows and column)

# %%
#import the pandas library
import pandas as pd
import numpy as np

# %% [markdown]
# Create Pandas DataFrame

# %%
from sklearn.datasets import load_boston

# %%
boston_datasets = load_boston()

# %%
type(boston_datasets)
# Out:
# sklearn.utils._bunch.Bunch

# %%
print(boston_datasets)
# Out:
# {'data': array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]]), 'target': array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#        18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#        15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#        13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
#        21.2, 19.3, 20. , 16.6, 14.4, 19.4, 19.7, 20.5, 25. , 23.4, 18.9,
# ...

# %%
 # pandas Dataframe
 boston_df = pd.DataFrame(boston_datasets.data, columns = boston_datasets.feature_names)

# %%
boston_df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
boston_df.shape
# Out:
# (506, 13)

# %% [markdown]
# Importing data frame csv file to Pandas DataFrame
#
# > Add blockquote

# %%
# csv file to oandas dataframe
diabetes_df = pd.read_csv('/content/diabetes (1).csv')

# %%
type(diabetes_df)
# Out:
# pandas.core.frame.DataFrame

# %%
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diabetes_df.shape
# Out:
# (768, 9)

# %% [markdown]
# Loading the data from a excel to a oandas dataframe:
#
# pd.read_excel(filepath)

# %%
# Exporting dataframe to a csv file
boston_df.to_csv('boston.csv')

# %% [markdown]
# Exporting pandas dataframe to an excel file:
#
# df.to_excel("file name")

# %%
# create a dataframe with numpy array
random_df = pd.DataFrame(np.random.rand(10,20))

# %%
random_df.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.833887  0.697612  0.565050  0.800261  0.901323  0.586531  0.737108
# 1  0.836682  0.250861  0.997197  0.769178  0.049200  0.128141  0.047006
# 2  0.660015  0.425003  0.629810  0.788961  0.748185  0.032380  0.956565
# 3  0.615089  0.206366  0.190348  0.657528  0.468129  0.076598  0.322746
# 4  0.462321  0.147365  0.058104  0.856243  0.585028  0.031220  0.467947
#
#          7         8         9         10        11        12        13  \
# 0  0.818164  0.388264  0.907840  0.279830  0.758470  0.911062  0.557208
# 1  0.651537  0.836597  0.801141  0.508392  0.816888  0.192715  0.853677
# 2  0.708265  0.781004  0.249458  0.087467  0.368489  0.475032  0.686431
# 3  0.724431  0.278118  0.167443  0.759985  0.933492  0.862255  0.762060
# 4  0.129283  0.065195  0.219062  0.697648  0.295161  0.604956  0.053999
#
#          14        15        16        17        18        19
# ...

# %%
random_df.shape
# Out:
# (10, 20)

# %% [markdown]
# Inspection the number of the rows and columnn

# %%
# fin ding the number of rows and columns
boston_df.shape
# Out:
# (506, 13)

# %%
# first five rows in data frame
boston_df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
# last 5 rows
boston_df.tail()
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 501  0.06263  0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527  0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076  0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959  0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741  0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 501     21.0  391.99   9.67
# 502     21.0  396.90   9.08
# 503     21.0  396.90   5.64
# 504     21.0  393.45   6.48
# 505     21.0  396.90   7.88

# %%
# Information of the data frame
boston_df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-5109323d4fed> in <cell line: 2>()
#       1 # Information of the data frame
# ----> 2 boston_df.info()
#
# NameError: name 'boston_df' is not defined
